# %% [markdown]
# <a href="https://colab.research.google.com/github/sowntharyakmr-boop/Data-Analysis-using-Python-Project/blob/main/DAY__5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sales = [1200,1500,1800,2000,1700]

total_sales = sum(sales)
average_sales = total_sales/len(sales)
highest_sales = max(sales)
lowest_sales = min(sales)

print("Total Sales:",total_sales)
print("Average Sales:",average_sales)
print("Highest Sales:",highest_sales)
print("Lowest Sales:",lowest_sales)
# Out:
# Total Sales: 8200
# Average Sales: 1640.0
# Highest Sales: 2000
# Lowest Sales: 1200

# %%
import numpy as np

products = ["Laptop","Mobile","Tablet","TV","Refrigilator"]
sales = [120,250,80,150,100]

total_sales = np.sum(sales)
average_sales = np.mean(sales)
highest_sales = np.max(sales)
lowest_sales = np.min(sales)

best_index = np.argmax(sales)
worst_index = np.argmin(sales)

print("Total Sales:",total_sales)
print("Average Sales:",average_sales)
print("Highest sales:",highest_sales)
print("Lowest Sales:",lowest_sales)
print("Best Selling Product:",products[best_index])

print("\nProduct Sales Report")
for i in range(len(products)):
  print(f"{products[i]}:{sales[i]}")
# Out:
# Total Sales: 700
# Average Sales: 140.0
# Highest sales: 250
# Lowest Sales: 80
# Best Selling Product: Mobile
#
# Product Sales Report
# Laptop:120
# Mobile:250
# Tablet:80
# TV:150
# Refrigilator:100

# %%
import pandas as pd

data = pd.Series([10,20,30,40])

print(data)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
import pandas as pd
data = pd.Series(
    [100,200,300],
    index=["AJAY","BALU","CHARMILA"]
)
print(data)
# Out:
# AJAY        100
# BALU        200
# CHARMILA    300
# dtype: int64

# %%
import pandas as pd

employee = {
    "ID":[101,102,103],
    "NAME":["Akilan","Sanjay","Priya"],
    "SALARY":[50000,60000,56000]
}
df = pd.DataFrame(employee)
print(df)
# Out:
#     ID    NAME  SALARY
# 0  101  Akilan   50000
# 1  102  Sanjay   60000
# 2  103   Priya   56000
