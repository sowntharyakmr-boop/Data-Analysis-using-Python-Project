# %% [markdown]
# <a href="https://colab.research.google.com/github/sowntharyakmr-boop/Data-Analysis-using-Python-Project/blob/main/Practical_Day_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
marks = np.array([56,89,80,70])
print(marks[3])
# Out:
# 70

# %%
def calculate_average(a,b,c):
  return(a+b+c)/3

try:
  a=int(input("Enter 1st number:"))
  b=int(input("Enter 2nd number:"))
  c=int(input("Enter 3rd number:"))
  print("calculate_average=",calculate_average(a,b,c))
except ValueError:
  print("Invalid Input")
  print("Invalid Input")
# Out:
# Enter 1st number:90
# Enter 2nd number:89
# Enter 3rd number:65
# calculate_average= 81.33333333333333
