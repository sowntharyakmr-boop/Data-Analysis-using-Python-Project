# %% [markdown]
# <a href="https://colab.research.google.com/github/sowntharyakmr-boop/Data-Analysis-using-Python-Project/blob/main/Day_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Expenses Tracker

# %%
Expenses = [100,250,300,150]
Total = sum(Expenses)
print("Expenses:",Expenses)
print("Total Expenses:",Total)
# Out:
# Expenses: [100, 250, 300, 150]
# Total Expenses: 800
